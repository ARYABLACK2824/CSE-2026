# %% [markdown]
# <a href="https://colab.research.google.com/github/ARYABLACK2824/CSE-2026/blob/main/Trends_With_CYCLICITY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

Ig,axes =plt.subplots(1,3,figsize=(30,5),dpi=100)

df = pd.read_csv("/content/drive/MyDrive/supermarket_sales - Sheet1.csv",parse_dates=['Date'], index_col='Date').plot(title="Trend only",legend=False,ax=axes[0])
df = pd.read_csv("/content/drive/MyDrive/supermarket_sales - Sheet1.csv",parse_dates=['Date'], index_col='Date').plot(title="Seasonality only",legend=False,ax=axes[1])
df = pd.read_csv("/content/drive/MyDrive/supermarket_sales - Sheet1.csv",parse_dates=['Date'], index_col='Date').plot(title="Trend & Seasonality",legend=False,ax=axes[2])
